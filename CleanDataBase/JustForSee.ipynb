# %%
import pandas as pd 
import numpy as np

# %%
df_ = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/CSVS/IncidenciasC.csv"

# %%
df = pd.read_csv(df_)

# %%
df.head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0        1        1        6        15           16      0        1      4
# 1        1        1        6        15           17     26       20     14
# 2        1        1        6        15           18      2        3      4
# 3        1        1        6        15           19      0        0      0
# 4        1        1        6        15           20     35       40     32
#
#    ABRIL  MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  \
# 0      5     4      4      8       7           6        3          7
# 1     18    13      8      7      13           6        4          7
# 2      6     3      5      6       4           4        4          2
# 3      0     0      0      1       0           0        1          5
# 4     38    59     66     55      65          53       79         68
#
#    DICIEMBRE  TOTAL_DELITOS  TMODVICC_2017
# 0          8             57              1
# ...

# %%
df_2 = df[['CVE_ENT','CVE_MUN','CVE_MOD','CVE_TIPO','CVE_SUBTIPO','ENERO','TMODVICC_2017','TOTAL_DELITOS']]

# %%
df_2.head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  TMODVICC_2017  \
# 0        1        1        6        15           16      0              1
# 1        1        1        6        15           17     26              1
# 2        1        1        6        15           18      2              1
# 3        1        1        6        15           19      0              1
# 4        1        1        6        15           20     35              1
#
#    TOTAL_DELITOS
# 0             57
# 1            122
# 2             46
# 3              8
# 4            604
