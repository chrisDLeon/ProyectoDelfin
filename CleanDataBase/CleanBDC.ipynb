# %%
import pandas as pd
import numpy as np

# %%
df_11 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2011/2011.csv"
df_12 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2012/2012.csv"
df_13 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2013/2013.csv"
df_14 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2014/2014.csv"
df_15 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2015/2015.csv"
df_16 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2016/2016.csv"
df_17 = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/2017/2017.csv"

# %%
df_2011 = pd.read_csv(df_11)
df_2012 = pd.read_csv(df_12)
df_2013 = pd.read_csv(df_13)
df_2014 = pd.read_csv(df_14)
df_2015 = pd.read_csv(df_15)
df_2016 = pd.read_csv(df_16)
df_2017 = pd.read_csv(df_17)

# %%
df_2015.BP1_32_1.value_counts()
# Out:
# 0.0    5675
# 1.0    2207
# Name: BP1_32_1, dtype: int64

# %%
df_2015.head()
# Out:
#    Unnamed: 0                 ID_DEL     UPM  VIV_SEL  HOGAR  ND_TIPO  \
# 0           0  0100155.01.01.02.08.1  100155        1      1        1
# 1           1  0100462.01.01.02.08.1  100462        1      1        1
# 2           2  0100467.04.01.02.02.1  100467        4      1        1
# 3           3  0102317.19.01.01.02.1  102317       19      1        1
# 4           4  0100738.02.01.02.02.1  100738        2      1        1
#
#    TD_TIPO  BPCOD  R_SEL  AREAM_OCU     ...     BP6_1  BP6_2  BP6_3  BP7_1  \
# 0        1      8      2       14.0     ...       NaN    NaN    NaN    NaN
# 1        1      8      2       14.0     ...       NaN    NaN    NaN    NaN
# 2        1      2      2       14.0     ...       NaN    NaN    NaN    NaN
# 3        1      2      1       14.0     ...       NaN    NaN    NaN    NaN
# 4        1      2      2       14.0     ...       NaN    NaN    NaN    NaN
#
#    FAC_DEL  EST_DIS  UPM_DIS  DOMINIO  ESTRATO  FAC_DEL_AM
# ...

# %%
df_2015.DOMINIO.value_counts()
# Out:
# U    30364
# C     9855
# R     4480
# Name: DOMINIO, dtype: int64

# %%
df_2015.DOMINIO.replace({'U':1,'C':2,'R':3},inplace = True)
df_2015.DOMINIO.value_counts()
# Out:
# 1    30364
# 2     9855
# 3     4480
# Name: DOMINIO, dtype: int64

# %%
df_2014.head()
# Out:
#    Unnamed: 0  CONTROL  VIV_SEL  HOGAR  ND_TIPO  TD_TIPO  BPCOD  R_SEL  \
# 0           0   140142        5      1        1        1      2      1
# 1           1   140049        5      1        1        1      4      1
# 2           2   140141        2      1        1        1      2      3
# 3           3   140060        2      1        1        1      8      5
# 4           4   100012        1      1        2        2      4      1
#
#    AREAM_OCU RESUL_H     ...      BP5_3  BP6_1  BP6_2  BP6_3  BP7_1  FAC_DEL  \
# 0       14.0       A     ...        NaN    NaN    NaN    NaN    NaN      178
# 1       14.0       A     ...        NaN    NaN    NaN    NaN    NaN      202
# 2       14.0       A     ...        NaN    NaN    NaN    NaN    NaN      170
# 3       14.0       A     ...        NaN    NaN    NaN    NaN    NaN     1225
# 4       14.0       A     ...        NaN    NaN    NaN    NaN    NaN      147
#
#    DOM  EST  UPM  FAC_DEL_AM
# 0    U    5  107       178.0
# ...

# %%
df_2014.DOM.value_counts()
# Out:
# U    29752
# C     9216
# R     4510
# Name: DOM, dtype: int64

# %%
df_2014.DOM.replace({'U':1,'C':2,'R':3},inplace = True)
df_2014.DOM.value_counts()
# Out:
# 1    29752
# 2     9216
# 3     4510
# Name: DOM, dtype: int64

# %%
df_2014.RESUL_H.value_counts()
# Out:
# A    43478
# Name: RESUL_H, dtype: int64

# %%
df_2014.RESUL_H.replace({'A':1},inplace = True)
df_2014.RESUL_H.value_counts()
# Out:
# 1    43478
# Name: RESUL_H, dtype: int64

# %%
df_2013.head()
# Out:
#    Unnamed: 0  CONTROL  VIV_SEL  HOGAR  ND_TIPO  TD_TIPO  BPCOD  R_SEL  \
# 0           0    10005        1      1        1        2      5      2
# 1           1    10005        1      1        2        2      5      2
# 2           2    10005        4      1        1        1      2      1
# 3           3    10005        5      1        1        1      3      1
# 4           4    10005        5      1        1        2      2      1
#
#   RESUL_H  BP1_1   ...     BP6_1  BP6_2  BP6_3  BP6_4  BP7_1  FAC_DEL  DOM  \
# 0       A      1   ...       NaN    NaN    NaN    NaN    NaN      700    U
# 1       A     11   ...       NaN    NaN    NaN    NaN    NaN      700    U
# 2       A     11   ...       NaN    NaN    NaN    NaN    NaN      175    U
# 3       A     12   ...       NaN    NaN    NaN    NaN    NaN      175    U
# 4       A      3   ...       NaN    NaN    NaN    NaN    NaN      175    U
#
#    EST  UPM  EST_SOC
# 0    6    3        3
# 1    6    3        3
# ...

# %%
df_2013.DOM.replace({'U':1,'C':2,'R':3},inplace = True)
df_2013.DOM.value_counts()
# Out:
# 1    37147
# 2     6980
# 3     2990
# Name: DOM, dtype: int64

# %%
df_2013.RESUL_H.replace({'A':1},inplace = True)
df_2013.RESUL_H.value_counts()
# Out:
# 1    47117
# Name: RESUL_H, dtype: int64

# %%
DF
# Out:
#    Unnamed: 0  CONTROL  VIV_SEL  HOGAR  ND_TIPO  BPCOD  R_SEL  BP1_1  BP1_2C  \
# 0           0    10001        1      1        1      8      1     11       1
# 1           1    10001        5      1        1      8      2      3       1
# 2           2    10002        1      1        1      2      3      5       1
# 3           3    10002        5      1        1      2      2      3       1
# 4           4    10004        5      1        1      2      1      4       1
#
#    BP1_3C ...   BP5_4  BP6_1  BP6_2  BP6_3  BP6_4  BP7_1  FAC_DEL  DOM  EST  \
# 0       1 ...     2.0    NaN    NaN    NaN    NaN    NaN      174    U    2
# 1       1 ...     2.0    NaN    NaN    NaN    NaN    NaN      348    U    2
# 2       1 ...     NaN    NaN    NaN    NaN    NaN    NaN      270    U    2
# 3       1 ...     NaN    NaN    NaN    NaN    NaN    NaN      270    U    2
# 4       1 ...     NaN    NaN    NaN    NaN    NaN    NaN      167    U    2
#
#    UPM
# 0    1
# 1    1
# 2    2
# 3    2
# ...

# %%
df_2012.DOM.replace({'U':1,'C':2,'R':3},inplace = True)
df_2012.DOM.value_counts()
# Out:
# 1    25021
# 2     5130
# 3     2342
# Name: DOM, dtype: int64

# %%
df_2011.head()
# Out:
#    Unnamed: 0  CONTROL  VIV_SEL  HOGAR  R_SEL  BPCOD  ND_TIPO  BP1_1  BP1_2C  \
# 0           0    10005        5      1      2      2        1      1       1
# 1           1    10005        5      1      2      2        2      4       1
# 2           2    10005        5      1      2      2        3      8       1
# 3           3    10005        5      1      2      2        4     12       1
# 4           4    10015        2      1      1      2        1      8       1
#
#    BP1_3C   ...     BP5_3  BP5_4  BP6_1  BP7_1  BP7_2  EST  UPM  CIUDAD  DOM  \
# 0       1   ...       NaN    NaN    NaN    NaN    NaN  163    1     NaN    U
# 1       1   ...       NaN    NaN    NaN    NaN    NaN  163    1     NaN    U
# 2       1   ...       NaN    NaN    NaN    NaN    NaN  163    1     NaN    U
# 3       1   ...       NaN    NaN    NaN    NaN    NaN  163    1     NaN    U
# 4       1   ...       NaN    NaN    NaN    NaN    NaN   75    2     NaN    U
#
#    FAC_DEL
# 0      446
# 1      446
# ...

# %%
df_2011.DOM.replace({'U':1,'C':2,'R':3},inplace = True)
df_2011.DOM.value_counts()
# Out:
# A    15175
# 1     5707
# 2     3357
# 3     2947
# Name: DOM, dtype: int64

# %%
df_2011.DOM.replace({'A':99},inplace = True)
df_2011.DOM.value_counts()
# Out:
# 99    15175
# 1      5707
# 2      3357
# 3      2947
# Name: DOM, dtype: int64

# %%
df_2016.head()
# Out:
#    Unnamed: 0     ID_VIV         ID_HOG            ID_PER  \
# 0           0  101318.05  0101318.05.01  0101318.05.01.03
# 1           1  101989.02  0101989.02.01  0101989.02.01.02
# 2           2  100777.01  0100777.01.02  0100777.01.02.01
# 3           3  101318.03  0101318.03.01  0101318.03.01.01
# 4           4  100457.03  0100457.03.01  0100457.03.01.03
#
#                   ID_DEL     UPM  VIV_SEL  HOGAR  ND_TIPO  TD_TIPO   ...     \
# 0  0101318.05.01.03.03.1  101318        5      1        1        1   ...
# 1  0101989.02.01.02.02.1  101989        2      1        1        1   ...
# 2  0100777.01.02.01.02.2  100777        1      2        2        2   ...
# 3  0101318.03.01.01.04.1  101318        3      1        1        1   ...
# 4  0100457.03.01.03.02.3  100457        3      1        3        3   ...
#
#    BP6_1  BP6_2  BP6_3 BP7_1  FAC_DEL  FAC_DEL_AM  DOMINIO  ESTRATO  EST_DIS  \
# 0     99     99     99    99      206       206.0        U        4        3
# ...

# %%
df_2016.DOMINIO.replace({'U':1,'C':2,'R':3},inplace = True)
df_2016.DOMINIO.value_counts()
# Out:
# 1    26712
# 2     8893
# 3     4421
# Name: DOMINIO, dtype: int64

# %%
df_2017.DOMINIO.replace({'U':1,'C':2,'R':3},inplace = True)
df_2017.DOMINIO.value_counts()
# Out:
# 1    30764
# 2     9401
# 3     4465
# Name: DOMINIO, dtype: int64

# %%
df_2017.head()
# Out:
#    Unnamed: 0      ID_VIV         ID_HOG            ID_PER  \
# 0           0   100172.02  0100172.02.01  0100172.02.01.02
# 1           1   100931.01  0100931.01.01  0100931.01.01.01
# 2           2   160114.20  0160114.20.01  0160114.20.01.01
# 3           3   100208.04  0100208.04.01  0100208.04.01.01
# 4           4  1409568.04  1409568.04.01  1409568.04.01.01
#
#                 ID_DEL      UPM  VIV_SEL  HOGAR  ND_TIPO  TD_TIPO   ...     \
# 0  0100172.02.01.02.09   100172        2      1        1        1   ...
# 1  0100931.01.01.01.03   100931        1      1        1        1   ...
# 2  0160114.20.01.01.02   160114       20      1        4        4   ...
# 3  0100208.04.01.01.03   100208        4      1        1        2   ...
# 4  1409568.04.01.01.02  1409568        4      1        1        1   ...
#
#    BP6_1  BP6_2 BP6_3  BP7_1  FAC_DEL  FAC_DEL_AM  DOMINIO  ESTRATO  EST_DIS  \
# 0     99     99    99     99      364         364        1        3        2
# ...

# %%
df_2011.to_csv("2011_C.csv")

# %%
df_2012.to_csv("2012_C.csv")
df_2013.to_csv("2013_C.csv")
df_2014.to_csv("2014_C.csv")
df_2015.to_csv("2015_C.csv")
df_2016.to_csv("2016_C.csv")
df_2017.to_csv("2017_C.csv")

# %%
df_2017.RESUL_H.replace({'A':1,'C':2,'R':3},inplace = True)
df_2017.RESUL_H.value_counts()
# Out:
# 1    44630
# Name: RESUL_H, dtype: int64

# %%
df_2017.to_csv("2017_C.csv")
