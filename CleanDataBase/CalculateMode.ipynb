# %%
import pandas as pd 
import numpy as np

# %%
df_EM = "C:/Users/chris/Documents/TRABAJO/PROYECTOS/PROGRAMA DELFIN/PROYECTOCRIMEN/CSVS/2017_EMC.csv"

# %%
df = pd.read_csv(df_EM)

# %%
df.head()
# Out:
#    VIV_SEL  HOGAR  ND_TIPO  TD_TIPO  BPCOD  R_SEL  RESUL_H  SEXO  EDAD  \
# 0        2      1        1        1      9      2        1     2    42
# 1        1      1        1        1      3      1        1     1    48
# 2       20      1        4        4      2      1        1     2    30
# 3        4      1        1        2      3      1        1     1    59
# 4        4      1        1        1      2      1        1     1    38
#
#    AREAM_OCU    ...     BP1_36_09  BP1_36_10  BP1_36_11  BP1_36_99  DOMINIO  \
# 0         14    ...             1          0          0          0        1
# 1         14    ...             9          9          9          9        1
# 2         14    ...             9          9          9          9        3
# 3         14    ...             9          9          9          9        1
# 4         14    ...             9          9          9          9        1
#
#    ESTRATO  EST_DIS  CVE_ENT  CVE_MUN  CLUSTERS
# ...

# %%
df.groupby(by = ['CVE_ENT','CVE_MUN'])['CLUSTERS'].value_counts()
# Out:
# CVE_ENT  CVE_MUN  CLUSTERS
# 1        1        1           955
#                   2             6
#          2        1             3
#          3        1            40
#          4        1             4
#          5        1           117
#          6        1            11
#          7        1            21
#          9        1            19
#          10       1             6
#          11       1            49
#                   2             1
# 2        1        1           221
#          2        1           842
#                   2             2
#          3        1            93
#                   2             1
#          4        1           946
#                   2             5
#          5        1            27
# 3        1        1            91
#          2        1           107
#          3        1           691
#                   2             1
#          8        1           466
#                   2             3
# ...

# %%
df.groupby(by = ['CVE_ENT','CVE_MUN'])['CLUSTERS'].value_counts().mode()
# Out:
# 0    1
# dtype: int64

# %%
from scipy import stats
df_mode = df.groupby(['CVE_ENT','CVE_MUN']).CLUSTERS.apply(lambda x:x.mode())

# %%
df_mode
# Out:
# CVE_ENT  CVE_MUN
# 1        1        0    1
#          2        0    1
#          3        0    1
#          4        0    1
#          5        0    1
#          6        0    1
#          7        0    1
#          9        0    1
#          10       0    1
#          11       0    1
# 2        1        0    1
#          2        0    1
#          3        0    1
#          4        0    1
#          5        0    1
# 3        1        0    1
#          2        0    1
#          3        0    1
#          8        0    1
#          9        0    1
# 4        1        0    1
#          2        0    1
#          3        0    1
#          4        0    1
#          5        0    1
#          6        0    1
#          7        0    1
#          8        0    1
#          9        0    1
#          10       0    1
#                       ..
# 32       16       0    0
#          17       0    0
#          18       0    0
#          19       0    0
#          20       0    0
# ...

# %%
df_mode = pd.DataFrame(df_mode)
df_mode
# Out:
#                    CLUSTERS
# CVE_ENT CVE_MUN
# 1       1       0         1
#         2       0         1
#         3       0         1
#         4       0         1
#         5       0         1
#         6       0         1
#         7       0         1
#         9       0         1
#         10      0         1
#         11      0         1
# 2       1       0         1
#         2       0         1
#         3       0         1
#         4       0         1
#         5       0         1
# 3       1       0         1
#         2       0         1
#         3       0         1
#         8       0         1
#         9       0         1
# 4       1       0         1
#         2       0         1
#         3       0         1
#         4       0         1
#         5       0         1
#         6       0         1
#         7       0         1
#         8       0         1
#         9       0         1
#         10      0         1
# ...                     ...
# ...

# %%
df_mode.to_csv('2017_ModeC.csv')
